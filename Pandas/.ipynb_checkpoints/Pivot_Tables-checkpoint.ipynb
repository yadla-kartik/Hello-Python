# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# #### Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    401     15   John  January      Q1
# 1  2023-01-02       B   West    568     65   Mary  January      Q1
# 2  2023-01-03       C  North    427     77    Bob  January      Q1
# 3  2023-01-04       D  South    562     77  Alice  January      Q1
# 4  2023-01-05       A   East    736     48   John  January      Q1
# 5  2023-01-06       B   West    567     66   Mary  January      Q1
# 6  2023-01-07       C  North    489     82    Bob  January      Q1
# 7  2023-01-08       D  South    147     64  Alice  January      Q1
# 8  2023-01-09       A   East    527     45   John  January      Q1
# 9  2023-01-10       B   West    673     66   Mary  January      Q1
# 10 2023-01-11       C  North    798     70    Bob  January      Q1
# 11 2023-01-12       D  South    596     60  Alice  January      Q1
# 12 2023-01-13       A   East    960     22   John  January      Q1
# 13 2023-01-14       B   West    508     93   Mary  January      Q1
# 14 2023-01-15       C  North    206     25    Bob  January      Q1
# 15 2023-01-16       D  South    314     93  Alice  January      Q1
# 16 2023-01-17       A   East    948     86   John  January      Q1
# 17 2023-01-18       B   West    628     34   Mary  January      Q1
# 18 2023-01-19       C  North    827     43    Bob  January      Q1
# 19 2023-01-20       D  South    108     74  Alice  January      Q1

# %%
pd.pivot_table(df, values = 'Sales', index='Region', columns='Product', aggfunc='max')
# Out:
# Product      A      B      C      D
# Region
# East     960.0    NaN    NaN    NaN
# North      NaN    NaN  827.0    NaN
# South      NaN    NaN    NaN  596.0
# West       NaN  673.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     714.4    NaN    NaN    NaN  43.2   NaN   NaN   NaN
# North      NaN    NaN  549.4    NaN   NaN   NaN  59.4   NaN
# South      NaN    NaN    NaN  345.4   NaN   NaN   NaN  73.6
# West       NaN  588.8    NaN    NaN   NaN  64.8   NaN   NaN

# %% [markdown]
# #### Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
